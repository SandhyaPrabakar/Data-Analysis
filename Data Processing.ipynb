# %%
import pandas as pd

# %%
cd/users/Sandhya/Desktop
# Out:
# /Users/sandhya/Desktop

# %%
sheet1=pd.read_excel(r'Data Analyst Intern Assignment - Excel.xlsx',sheet_name='UserDetails.csv')
sheet2=pd.read_excel(r'Data Analyst Intern Assignment - Excel.xlsx',sheet_name='CookingSessions.csv')
sheet3=pd.read_excel(r'Data Analyst Intern Assignment - Excel.xlsx',sheet_name='OrderDetails.csv')

# %%
#Combine sheet 2 and 3 
merged_data=pd.merge(sheet3,sheet2,on='Session ID',how='left')
merged_data=merged_data.drop(columns=['User ID_x','Meal Type_x','Dish Name_x'])
merged_data=merged_data.rename(columns={'User ID_y':'User ID','Meal Type_y':'Meal Type','Dish Name_y':'Dish Name'})
merged_data
# Out:
#     Order ID Order Date Order Status  Amount (USD) Time of Day  Rating  \
# 0     1001.0 2024-12-01    Completed          15.0       Night     5.0
# 1     1002.0 2024-12-01    Completed          10.0         Day     4.0
# 2     1003.0 2024-12-02     Canceled          12.5       Night     NaN
# 3     1004.0 2024-12-02    Completed           8.0     Morning     4.0
# 4     1005.0 2024-12-03    Completed           9.0         Day     4.0
# 5     1006.0 2024-12-03    Completed          14.0       Night     4.0
# 6     1007.0 2024-12-04    Completed          13.5       Night     4.0
# 7     1008.0 2024-12-04     Canceled          11.0         Day     NaN
# 8     1009.0 2024-12-05    Completed          12.0       Night     5.0
# 9     1010.0 2024-12-05    Completed           7.0     Morning     4.0
# 10    1011.0 2024-12-06    Completed           8.5     Morning     4.0
# 11    1012.0 2024-12-06    Completed          12.5       Night     4.0
# ...

# %%
merged_data=pd.merge(merged_data,sheet1,on='User ID',how='left')
merged_data
# Out:
#     Order ID Order Date Order Status  Amount (USD) Time of Day  Rating  \
# 0     1001.0 2024-12-01    Completed          15.0       Night     5.0
# 1     1002.0 2024-12-01    Completed          10.0         Day     4.0
# 2     1003.0 2024-12-02     Canceled          12.5       Night     NaN
# 3     1004.0 2024-12-02    Completed           8.0     Morning     4.0
# 4     1005.0 2024-12-03    Completed           9.0         Day     4.0
# 5     1006.0 2024-12-03    Completed          14.0       Night     4.0
# 6     1007.0 2024-12-04    Completed          13.5       Night     4.0
# 7     1008.0 2024-12-04     Canceled          11.0         Day     NaN
# 8     1009.0 2024-12-05    Completed          12.0       Night     5.0
# 9     1010.0 2024-12-05    Completed           7.0     Morning     4.0
# 10    1011.0 2024-12-06    Completed           8.5     Morning     4.0
# 11    1012.0 2024-12-06    Completed          12.5       Night     4.0
# ...

# %%
merged_data['Rating'] = merged_data['Rating'].fillna(0)

# %%
merged_data.to_excel("output.xlsx")
